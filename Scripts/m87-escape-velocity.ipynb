# %%
import numpy as np
import matplotlib.pyplot as plt
r_0 = 120. #parsecs
r = np.linspace(0., 10.,100) #parsecs
v_r = 0 #km/s
sigma = 500. #km/s
v_0 = np.sqrt(v_r**2 + 2*(sigma**2)*np.log((r*1000000)/r_0))

#vr=2300
#print np.sqrt(vr**2 + 2*(sigma**2)*np.log(r/r_0))

# %%
file_name = 'velocity_behavior.png'
plt.figure(figsize=(5,5))
ax = plt.gca()
ax.tick_params(direction='in')
plt.plot(r, v_0,label='Velocity Behavior')
#plt.axvline(x=2300,color='red',linestyle='--',linewidth=1,label='Observed Velocity \n 2300 km/s')
plt.title('Velocity Behavior of an Object Escaping M87')
plt.xlabel('Distance when radial vel becomes 2300km/s (Mpc)')
plt.ylabel('Ejection Velocity (km/s)')
plt.legend()
save_file = './Images/'+file_name
plt.savefig(save_file)
plt.show()

# %%
print "Myrs required to travel 1Mpc at 3000km/s:",1400000/3000, 'Myr'

# %%
print 'tangential velocity required to reach 85kpc in 333 Myr:',85000/2100,'km/s'

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
G = 6.67e-11
M = (6.0e12)*1.99e30
def velocity_behavior(v_0):
    sigma = 500. #km/s
    r_0 = 120
    r = np.linspace(120,50000000,1000)
    v_r = np.sqrt(v_0**2 - 2*(sigma**2)*np.log((r)/r_0))
    return v_r
"""
for i,f in enumerate(v_r):
    if np.isnan(v_r[i]):
        v_r[i] = 0
    else:
        None
"""

ve = np.sqrt(2*G*M/(1000000*3.08e16))
print ve/1000
# Out:
# 227.407466553

# %%
vr_1500 = velocity_behavior(2000)
vr_2300 = velocity_behavior(2200)
vr_3000 = velocity_behavior(3100)
vr_3300 = velocity_behavior(3250)
file_name = 'velocity_behavior.png'
plt.figure(figsize=(5,5))
ax = plt.gca()
ax.tick_params(direction='in')
plt.semilogx(r, vr_1500, label='1500 km/s')
plt.semilogx(r, vr_2300,label='2200 km/s Eject')
plt.semilogx(r, vr_3000,label='3100 km/s Eject')
plt.semilogx(r, vr_3300,label='3250 km/s Eject')
plt.axhline(y=2300,color='red',linestyle='--',linewidth=1,label='Observed Velocity \n 2300 km/s')
plt.title('Velocity Behavior of an Object Escaping M87')
plt.xlabel('Radial Distance From M87 (pc)')
plt.ylabel('Radial Velocity (km/s)')
plt.legend()
save_file = './Images/'+file_name
plt.savefig(save_file)
plt.show()
# Out:
# /Users/sean/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Dark Matter potential#
V_s = 591.
R_s = 42000.
r_f = 50000.
R = np.linspace(0,500000,1000)
phi = (V_s/2)*np.log(R_s**2 + R**2)
v_i = np.sqrt(2300**2 + (V_s**2)*(np.log(R_s**2 + R**2) - np.log(R_s**2 + r_0**2)))
plt.plot(R, v_i)
plt.show()
